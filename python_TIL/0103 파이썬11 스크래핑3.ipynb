# %%
1 www.hanbit.co.kr 입력
2 http://www.hanbit.co.kr/index.html + 신호(정상 200, 잘못된주소 40x, 서버오류 50x)
3 웹브라우저가 http://www.hanbit.co.kr/index.html 해석
4 결과화면 출력

# %%
# 세션(server <~> client) 시작하기

# %%
requests (+get/post) - dictionary
urllib - binary

# %%
# 로그인 모듈

import requests
from bs4 import BeautifulSoup

# %%
USER='silvery0224'
PASS='jd2112jd'

# %%
# 세션(server <~> client) 시작하기
session=requests.session()        # 승차권
login_info={'m_id':USER, 'm_passwd':PASS}

url_login='https://www.hanbit.co.kr/member/login_proc.php'
res=session.post(url_login, data=login_info)

# %%
res
# Out:
# <Response [200]>

# %%
res2=session.get('http://www.hanbit.co.kr/myhanbit/myhanbit.html')
res2
# Out:
# <Response [200]>

# %%
#container > div > div.sm_mymileage > dl.mileage_section1 > dd > span

#container > div > div.sm_mymileage > dl.mileage_section2 > dd > span

soup=BeautifulSoup(res2.text, 'html.parser')
mileage=soup.select_one('#container > div > div.sm_mymileage > dl.mileage_section1 > dd > span').text
ecoin=soup.select_one('#container > div > div.sm_mymileage > dl.mileage_section2 > dd > span').text
print(mileage)
print(ecoin)
# Out:
# 2,000
# 0

# %%
# url_login='https://www.hanbit.co.kr/member/login_proc9.php'
# res3=session.post(url_login, data=login_info)
# res.raise_for_status()

# %%
# 웹브라우저 스크래핑     Selenium
# pip install selenium

# cmd 에서 이용하는 웹    phantomjs

# %%
from selenium import webdriver
url='http://www.naver.com'

# phantomjs 드라이버 추출
browser=webdriver.PhantomJS()

# 3초 대기
browser.implicitly_wait(3)

# url 읽기
browser.get(url)

# 화면 캡쳐 및 저장
browser.save_screenshot('myshot.png')

# 브라우저 종료
browser.quit()
# Out:
# C:\Users\student\Anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
import urllib.request as req
page=req.urlopen('http://www.rottentomatoes.com')
doc=page.read()
soup2=BeautifulSoup(doc, 'html.parser')
movies=soup2.find(id='homepage-top-box-office')
movie_list=movies.find_all('td', class_='middle_col')

#movie_list.get('a')
for movie in movie_list:
    print(movie.get_text())
    print('http://rottentomatoes.com'+movie.find('a').get('href'))
# Out:
# Star Wars: The Rise of Skywalker
#
# http://rottentomatoes.com/m/star_wars_the_rise_of_skywalker
#
# Jumanji: The Next Level
#
# http://rottentomatoes.com/m/jumanji_the_next_level
#
# Little Women
#
# http://rottentomatoes.com/m/little_women_2019
#
# Frozen II
#
# http://rottentomatoes.com/m/frozen_ii
#
# Spies in Disguise
#
# http://rottentomatoes.com/m/spies_in_disguise
#
# Knives Out
#
# http://rottentomatoes.com/m/knives_out
#
# Uncut Gems
#
# http://rottentomatoes.com/m/uncut_gems
#
# Cats
#
# http://rottentomatoes.com/m/cats_2019
#
# Bombshell
#
# http://rottentomatoes.com/m/bombshell_2019
#
# Richard Jewell
#
# http://rottentomatoes.com/m/richard_jewell

# %%
import requests
from bs4 import BeautifulSoup
import requests 
url3='https://stackoverflow.com/questions/tagged/python'
response=requests.get(url3)
soup3=BeautifulSoup(response.text, 'html.parser')
links=[]
for link in soup3.select('div.question-summary h3 a'):       # 질문페이지 링크
    links.append(link.attrs['href'])
    #print('http://www.stackoverflow.com'+link.attrs['href'])
for link in links:
    url4='http://www.stackoverflow.com'+link        # 답변 페이지
    response2=requests.get(url4)
    text=response.text
    soup4=BeautifulSoup(text, 'html.parser')
    print('question\n')
    for x in soup4.select('div.postcell div.post-text p'):
        print(x.text)
    print('\nanswer\n')
    for x in soup4.select('div.answercell div.post-text p'):
        print(x.text)
    print('='*40, '\n')
# Out:
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================
#
# question
#
#
# answer
#
# ========================================

# %%
# 1. 파이썬 키워드에 대한 질문 추출

import requests
from bs4 import BeautifulSoup
import urllib.request as req

url='https://search.naver.com/search.naver?sm=tab_hty.top&where=kin&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&oquery=%ED%8C%8C%EC%9D%B4%EC%8D%AC&tqi=UlJrKlp0Jy0ssE0doKdssssstrV-371680'
response=requests.get(url)
soup=BeautifulSoup(response.text, 'html.parser')
questions=soup.select('#elThumbnailResultArea')
question_list=questions.find_all('#elThumbnailResultArea > dl > dt > a')
print(question_list)
    


# url3='https://stackoverflow.com/questions/tagged/python'
# response=requests.get(url3)
# soup3=BeautifulSoup(response.text, 'html.parser')
# links=[]
# for link in soup3.select('div.question-summary h3 a'):       # 질문페이지 링크
#     links.append(link.attrs['href'])
#     #print('http://www.stackoverflow.com'+link.attrs['href'])
# for link in links:
#     url4='http://www.stackoverflow.com'+link        # 답변 페이지
#     response2=requests.get(url4)
#     text=response.text
#     soup4=BeautifulSoup(text, 'html.parser')
#     print('question\n')
#     for x in soup4.select('div.postcell div.post-text p'):
#         print(x.text)
#     print('\nanswer\n')
#     for x in soup4.select('div.answercell div.post-text p'):
#         print(x.text)
#     print('='*40, '\n')
#elThumbnailResultArea > li:nth-child(1) > dl > dt > a

#elThumbnailResultArea > li:nth-child(2) > dl > dt > a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-925b766ab59f> in <module>
#       9 soup=BeautifulSoup(response.text, 'html.parser')
#      10 questions=soup.select('#elThumbnailResultArea')
# ---> 11 question_list=questions.find_all('#elThumbnailResultArea > dl > dt > a')
#      12 print(question_list)
#      13
#
# AttributeError: 'list' object has no attribute 'find_all'

# %%
2. 1페이지에 있는 질문 모두 추출

# %%
3. 1~10 페이지에 있는 질문 모두 추출

# %%
4. 1~10 페이지에 있는 질문/답변 모두 추출

# %%
5. 추출한 전체 결과에 대해 '초보' 라는 단어가 등장한 횟수 출력
